# %%
import pandas as pd

# Usando pyarrow
import pyarrow.parquet as pq

# Ruta al archivo Parquet
ruta_archivo = 'horizon_work_programmes.parquet'

# Usando pyarrow
tabla = pq.read_table(ruta_archivo)
df = tabla.to_pandas()
df
# Out:
#     Work Programme                                        Call  \
# 0           health            HORIZON-HLTH-2023-STAYHLTH-01-01
# 1           health  HORIZON-HLTH-2024-STAYHLTH-01-02-two-stage
# 2           health  HORIZON-HLTH-2024-STAYHLTH-01-05-two-stage
# 3           health             HORIZON-HLTH-2023-ENVHLTH-02-01
# 4           health             HORIZON-HLTH-2023-ENVHLTH-02-02
# ..             ...                                         ...
# 654           food            HORIZON-CL6-2024-GOVERNANCE-01-9
# 655           food           HORIZON-CL6-2024-GOVERNANCE-01-10
# 656           food           HORIZON-CL6-2024-GOVERNANCE-01-11
# 657           food           HORIZON-CL6-2024-GOVERNANCE-01-12
# 658           food           HORIZON-CL6-2024-GOVERNANCE-01-13
#
#                                                 Budget  \
# 0                          EUR 15.00 and 20.00 million
# 1                           EUR 8.00 and 10.00 million
# ...
