# %%
import pyarrow.parquet as pq

# Especifica la ruta de tu archivo Parquet
path = 'EIC_work_programmes.parquet'

# Lee el archivo Parquet
table = pq.read_table(path)

# Convierte la tabla en un DataFrame de pandas
df = table.to_pandas()

# Ahora puedes trabajar con 'df' como un DataFrame de pandas
df
# Out:
#              Work Programme  \
# 0  EIC Pathfinder Challenge
# 1  EIC Pathfinder Challenge
# 2  EIC Pathfinder Challenge
# 3  EIC Pathfinder Challenge
# 4  EIC Pathfinder Challenge
# 5  EIC Transition Challenge
# 6  EIC Transition Challenge
# 7  EIC Transition Challenge
#
#                                            Challenge  \
# 0  EIC Pathfinder Challenge: Clean and efficient ...
# 1  EIC Pathfinder Challenge: Architecture, Engine...
# 2     EIC Pathfinder Challenge: Precision nutrition
# 3  EIC Pathfinder Challenge: Responsible electron...
# 4  EIC Pathfinder Challenge: In-space solar energ...
# 5  EIC Transition Challenge: Full scale Micro-Nan...
# 6  EIC Transition Challenge: Environmental intell...
# 7  EIC Transition Challenge: Chip-scale optical f...
#
#                                 Background and Scope  \
# 0  Cooling is an essential process across many ar...
# 1  Life cycle greenhouse gas (GHG) emissions of b...
# 2  Dietary guidelines provide recommendations on ...
# ...
